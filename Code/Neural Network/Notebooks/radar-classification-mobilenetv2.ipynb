# %% [markdown]
# # Radar Classification by MobilenetV2

# %% [markdown]
# #### **NOTE：** You can also visit https://www.kaggle.com/code/yanqihong/radar-classification-mobilenetv2/edit/run/182872183 to run the code directly.

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from random import randint
import tensorflow_hub as hub

import requests
from PIL import Image
from io import BytesIO

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Data Process

# %%
import os
class_names=os.listdir('/kaggle/input/radar-data-cfar/image_data_cfar/image_data')
print(class_names)
# Out:
# ['stand', 'drink', 'walk', 'sit', 'fall', 'pick']

# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import matplotlib.pyplot as plt
 
import itertools
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model


#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from tensorflow.keras.preprocessing.image import ImageDataGenerator



# specifically for cnn
from tensorflow.keras.layers import Dropout, Flatten,Activation
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
 
import tensorflow as tf
import random as rn

# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
import cv2                  
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

# %%
X=[]
Z=[]
IMG_SIZE=224
WALK_DIR='/kaggle/input/radar-data-cfar/image_data_cfar/image_data/walk'
FALL_DIR='/kaggle/input/radar-data-cfar/image_data_cfar/image_data/fall'
DRINK_DIR='/kaggle/input/radar-data-cfar/image_data_cfar/image_data/drink'
PICK_DIR='/kaggle/input/radar-data-cfar/image_data_cfar/image_data/pick'
SIT_DIR='/kaggle/input/radar-data-cfar/image_data_cfar/image_data/sit'
STAND_DIR='/kaggle/input/radar-data-cfar/image_data_cfar/image_data/stand'

# %%
def assign_label(img,movement_type):
    return movement_type

# %%
def make_train_data(movement_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,movement_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
        img = np.array(img)
#         img[:, :, 2] = 0
#         img[:, :, 1] = 0
#         img[:, :, 0] = 0
        
        #1: DR 0:RT 2: DT
        X.append(img)
        Z.append(str(label))

# %%
make_train_data('walk',WALK_DIR)
make_train_data('fall',FALL_DIR)
make_train_data('drink',DRINK_DIR)
make_train_data('pick',PICK_DIR)
make_train_data('sit',SIT_DIR)
make_train_data('stand',STAND_DIR)
# Out:
# 100%|██████████| 288/288 [00:02<00:00, 139.32it/s]
# 100%|██████████| 197/197 [00:01<00:00, 146.59it/s]
# 100%|██████████| 288/288 [00:01<00:00, 147.03it/s]
# 100%|██████████| 287/287 [00:01<00:00, 149.80it/s]
# 100%|██████████| 289/289 [00:01<00:00, 149.18it/s]
# 100%|██████████| 287/287 [00:01<00:00, 144.76it/s]

# %%
fig,ax=plt.subplots(3,3)
fig.set_size_inches(15,15)
for i in range(3):
    for j in range (3):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Movement: '+Z[l])
        
plt.tight_layout()

# %%
from keras.utils import to_categorical
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,6)
X=np.array(X)
X=X/255

# %%
x_data,x_val,y_data,y_val=train_test_split(X,Y,test_size=0.2,random_state=42)
x_train,x_test,y_train,y_test=train_test_split(x_data,y_data,test_size=0.2,random_state=42)

np.random.seed(42)
rn.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## Transfer Learning

# %%
model_name = "mobilenetv2-140-224"
model_handle_map = {
  "mobilenetv2-140-224": "/kaggle/input/mobilenet-v2/tensorflow2/140-224-feature-vector/2",
}
model_image_size_map = {
  "mobilenetv2-140-224": 224,
}
model_handle = model_handle_map.get(model_name)
pixels = model_image_size_map.get(model_name, 224)
print(f"Selected model: {model_name} : {model_handle}")
IMAGE_SIZE = (pixels, pixels)
print(f"Input size {IMAGE_SIZE}")
num_classes = 6
img_size = (224,224, 3)
# Out:
# Selected model: mobilenetv2-140-224 : /kaggle/input/mobilenet-v2/tensorflow2/140-224-feature-vector/2
# Input size (224, 224)

# %%
do_fine_tuning = False 

print("Building model with", model_handle)
model = tf.keras.Sequential([
    # Explicitly define the input shape so the model can be properly
    # loaded by the TFLiteConverter
    tf.keras.layers.InputLayer(input_shape=IMAGE_SIZE + (3,)),
    hub.KerasLayer(model_handle, trainable=do_fine_tuning),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Dense(6,
                          kernel_regularizer=tf.keras.regularizers.l2(0.001))
])
model.build((None,)+IMAGE_SIZE+(3,))
model.summary()
# Out:
# Building model with /kaggle/input/mobilenet-v2/tensorflow2/140-224-feature-vector/2
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1792)              4363712
#
#  dropout (Dropout)           (None, 1792)              0
#
#  dense (Dense)               (None, 6)                 10758
#
# =================================================================
# Total params: 4,374,470
# Trainable params: 10,758
# Non-trainable params: 4,363,712
# _________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
batch_size=128
epochs=100


datagen = ImageDataGenerator()

datagen.fit(x_train)
from tensorflow.keras.callbacks import LearningRateScheduler
def scheduler(epoch, lr):
     if epoch < 50:
         return lr
     else:
         return lr * np.exp(-0.1)
callback = LearningRateScheduler(scheduler)
model.compile(
  optimizer='adam', 
  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])



checkpoint = ModelCheckpoint('model/training_{epoch:02d}.keras',  # Model file name with epoch number
                             save_best_only=True,          # Set to True to save only the best model
                             save_weights_only=False,       # Set to True to save only the weights
                             monitor='val_accuracy',            # Metric to monitor
                             mode='auto',                   # Mode to decide whether to minimize or maximize the monitored metric
                             verbose=1)                     # Verbosity mode

hist = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                              epochs=epochs,
                              validation_data=(x_val, y_val),
                              verbose=1,
                              steps_per_epoch=x_train.shape[0] // batch_size,
                              callbacks=[checkpoint, callback])
# Out:
# Epoch 1/100
# 8/8 [==============================] - ETA: 0s - loss: 1.8541 - accuracy: 0.2560
# Epoch 1: val_accuracy improved from -inf to 0.43902, saving model to model/training_01.keras
# 8/8 [==============================] - 13s 476ms/step - loss: 1.8541 - accuracy: 0.2560 - val_loss: 1.5309 - val_accuracy: 0.4390 - lr: 0.0010
# Epoch 2/100
# 8/8 [==============================] - ETA: 0s - loss: 1.5327 - accuracy: 0.4316
# Epoch 2: val_accuracy improved from 0.43902 to 0.61585, saving model to model/training_02.keras
# 8/8 [==============================] - 2s 266ms/step - loss: 1.5327 - accuracy: 0.4316 - val_loss: 1.3081 - val_accuracy: 0.6159 - lr: 0.0010
# Epoch 3/100
# 8/8 [==============================] - ETA: 0s - loss: 1.3308 - accuracy: 0.5414
# Epoch 3: val_accuracy improved from 0.61585 to 0.72866, saving model to model/training_03.keras
# 8/8 [==============================] - 2s 259ms/step - loss: 1.3308 - accuracy: 0.5414 - val_loss: 1.1496 - val_accuracy: 0.7287 - lr: 0.0010
# Epoch 4/100
# 8/8 [==============================] - ETA: 0s - loss: 1.2086 - accuracy: 0.6035
# Epoch 4: val_accuracy improved from 0.72866 to 0.73780, saving model to model/training_04.keras
# 8/8 [==============================] - 2s 293ms/step - loss: 1.2086 - accuracy: 0.6035 - val_loss: 1.0775 - val_accuracy: 0.7378 - lr: 0.0010
# Epoch 5/100
# 8/8 [==============================] - ETA: 0s - loss: 1.1332 - accuracy: 0.6394
# Epoch 5: val_accuracy improved from 0.73780 to 0.76524, saving model to model/training_05.keras
# 8/8 [==============================] - 2s 266ms/step - loss: 1.1332 - accuracy: 0.6394 - val_loss: 1.0265 - val_accuracy: 0.7652 - lr: 0.0010
# Epoch 6/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0880 - accuracy: 0.6863
# Epoch 6: val_accuracy did not improve from 0.76524
# 8/8 [==============================] - 2s 241ms/step - loss: 1.0880 - accuracy: 0.6863 - val_loss: 1.0079 - val_accuracy: 0.7561 - lr: 0.0010
# Epoch 7/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0423 - accuracy: 0.7119
# Epoch 7: val_accuracy did not improve from 0.76524
# 8/8 [==============================] - 2s 234ms/step - loss: 1.0423 - accuracy: 0.7119 - val_loss: 0.9836 - val_accuracy: 0.7622 - lr: 0.0010
# Epoch 8/100
# 8/8 [==============================] - ETA: 0s - loss: 0.9968 - accuracy: 0.7484
# Epoch 8: val_accuracy improved from 0.76524 to 0.78049, saving model to model/training_08.keras
# 8/8 [==============================] - 2s 263ms/step - loss: 0.9968 - accuracy: 0.7484 - val_loss: 0.9565 - val_accuracy: 0.7805 - lr: 0.0010
# Epoch 9/100
# 8/8 [==============================] - ETA: 0s - loss: 0.9809 - accuracy: 0.7386
# Epoch 9: val_accuracy improved from 0.78049 to 0.78963, saving model to model/training_09.keras
# 8/8 [==============================] - 2s 272ms/step - loss: 0.9809 - accuracy: 0.7386 - val_loss: 0.9521 - val_accuracy: 0.7896 - lr: 0.0010
# Epoch 10/100
# 8/8 [==============================] - ETA: 0s - loss: 0.9830 - accuracy: 0.7418
# Epoch 10: val_accuracy did not improve from 0.78963
# 8/8 [==============================] - 2s 258ms/step - loss: 0.9830 - accuracy: 0.7418 - val_loss: 0.9320 - val_accuracy: 0.7835 - lr: 0.0010
# Epoch 11/100
# 8/8 [==============================] - ETA: 0s - loss: 0.9264 - accuracy: 0.7745
# Epoch 11: val_accuracy improved from 0.78963 to 0.79878, saving model to model/training_11.keras
# 8/8 [==============================] - 2s 260ms/step - loss: 0.9264 - accuracy: 0.7745 - val_loss: 0.9176 - val_accuracy: 0.7988 - lr: 0.0010
# Epoch 12/100
# 8/8 [==============================] - ETA: 0s - loss: 0.9351 - accuracy: 0.7702
# Epoch 12: val_accuracy did not improve from 0.79878
# 8/8 [==============================] - 2s 228ms/step - loss: 0.9351 - accuracy: 0.7702 - val_loss: 0.9229 - val_accuracy: 0.7866 - lr: 0.0010
# Epoch 13/100
# 8/8 [==============================] - ETA: 0s - loss: 0.9061 - accuracy: 0.7898
# Epoch 13: val_accuracy improved from 0.79878 to 0.80488, saving model to model/training_13.keras
# 8/8 [==============================] - 2s 259ms/step - loss: 0.9061 - accuracy: 0.7898 - val_loss: 0.8885 - val_accuracy: 0.8049 - lr: 0.0010
# Epoch 14/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8987 - accuracy: 0.7876
# Epoch 14: val_accuracy improved from 0.80488 to 0.81707, saving model to model/training_14.keras
# 8/8 [==============================] - 2s 264ms/step - loss: 0.8987 - accuracy: 0.7876 - val_loss: 0.8883 - val_accuracy: 0.8171 - lr: 0.0010
# Epoch 15/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8878 - accuracy: 0.8017
# Epoch 15: val_accuracy improved from 0.81707 to 0.82012, saving model to model/training_15.keras
# 8/8 [==============================] - 2s 262ms/step - loss: 0.8878 - accuracy: 0.8017 - val_loss: 0.8709 - val_accuracy: 0.8201 - lr: 0.0010
# Epoch 16/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8571 - accuracy: 0.8192
# Epoch 16: val_accuracy did not improve from 0.82012
# 8/8 [==============================] - 2s 236ms/step - loss: 0.8571 - accuracy: 0.8192 - val_loss: 0.8730 - val_accuracy: 0.8079 - lr: 0.0010
# Epoch 17/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8570 - accuracy: 0.8137
# Epoch 17: val_accuracy improved from 0.82012 to 0.82317, saving model to model/training_17.keras
# 8/8 [==============================] - 2s 256ms/step - loss: 0.8570 - accuracy: 0.8137 - val_loss: 0.8699 - val_accuracy: 0.8232 - lr: 0.0010
# Epoch 18/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8599 - accuracy: 0.8115
# Epoch 18: val_accuracy improved from 0.82317 to 0.82927, saving model to model/training_18.keras
# 8/8 [==============================] - 2s 260ms/step - loss: 0.8599 - accuracy: 0.8115 - val_loss: 0.8562 - val_accuracy: 0.8293 - lr: 0.0010
# Epoch 19/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8338 - accuracy: 0.8223
# Epoch 19: val_accuracy did not improve from 0.82927
# 8/8 [==============================] - 2s 230ms/step - loss: 0.8338 - accuracy: 0.8223 - val_loss: 0.8539 - val_accuracy: 0.8262 - lr: 0.0010
# Epoch 20/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8192 - accuracy: 0.8279
# Epoch 20: val_accuracy did not improve from 0.82927
# 8/8 [==============================] - 2s 230ms/step - loss: 0.8192 - accuracy: 0.8279 - val_loss: 0.8416 - val_accuracy: 0.8262 - lr: 0.0010
# Epoch 21/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8296 - accuracy: 0.8312
# Epoch 21: val_accuracy did not improve from 0.82927
# 8/8 [==============================] - 2s 230ms/step - loss: 0.8296 - accuracy: 0.8312 - val_loss: 0.8449 - val_accuracy: 0.8293 - lr: 0.0010
# Epoch 22/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8176 - accuracy: 0.8388
# Epoch 22: val_accuracy did not improve from 0.82927
# 8/8 [==============================] - 2s 233ms/step - loss: 0.8176 - accuracy: 0.8388 - val_loss: 0.8444 - val_accuracy: 0.8232 - lr: 0.0010
# Epoch 23/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.8034 - accuracy: 0.8538
# Epoch 23: val_accuracy improved from 0.82927 to 0.83537, saving model to model/training_23.keras
# 8/8 [==============================] - 2s 252ms/step - loss: 0.8045 - accuracy: 0.8529 - val_loss: 0.8364 - val_accuracy: 0.8354 - lr: 0.0010
# Epoch 24/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8120 - accuracy: 0.8388
# Epoch 24: val_accuracy did not improve from 0.83537
# 8/8 [==============================] - 2s 239ms/step - loss: 0.8120 - accuracy: 0.8388 - val_loss: 0.8337 - val_accuracy: 0.8232 - lr: 0.0010
# Epoch 25/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7970 - accuracy: 0.8529
# Epoch 25: val_accuracy improved from 0.83537 to 0.85366, saving model to model/training_25.keras
# 8/8 [==============================] - 2s 294ms/step - loss: 0.7970 - accuracy: 0.8529 - val_loss: 0.8210 - val_accuracy: 0.8537 - lr: 0.0010
# Epoch 26/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7708 - accuracy: 0.8584
# Epoch 26: val_accuracy did not improve from 0.85366
# 8/8 [==============================] - 2s 268ms/step - loss: 0.7708 - accuracy: 0.8584 - val_loss: 0.8236 - val_accuracy: 0.8476 - lr: 0.0010
# Epoch 27/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7773 - accuracy: 0.8649
# Epoch 27: val_accuracy did not improve from 0.85366
# 8/8 [==============================] - 2s 234ms/step - loss: 0.7773 - accuracy: 0.8649 - val_loss: 0.8112 - val_accuracy: 0.8506 - lr: 0.0010
# Epoch 28/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7719 - accuracy: 0.8682
# Epoch 28: val_accuracy did not improve from 0.85366
# 8/8 [==============================] - 2s 237ms/step - loss: 0.7719 - accuracy: 0.8682 - val_loss: 0.8651 - val_accuracy: 0.8049 - lr: 0.0010
# Epoch 29/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7918 - accuracy: 0.8442
# Epoch 29: val_accuracy did not improve from 0.85366
# 8/8 [==============================] - 2s 230ms/step - loss: 0.7918 - accuracy: 0.8442 - val_loss: 0.8197 - val_accuracy: 0.8354 - lr: 0.0010
# Epoch 30/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7816 - accuracy: 0.8643
# Epoch 30: val_accuracy did not improve from 0.85366
# 8/8 [==============================] - 2s 233ms/step - loss: 0.7816 - accuracy: 0.8643 - val_loss: 0.8403 - val_accuracy: 0.8232 - lr: 0.0010
# Epoch 31/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7556 - accuracy: 0.8736
# Epoch 31: val_accuracy did not improve from 0.85366
# 8/8 [==============================] - 2s 263ms/step - loss: 0.7556 - accuracy: 0.8736 - val_loss: 0.8054 - val_accuracy: 0.8445 - lr: 0.0010
# Epoch 32/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7444 - accuracy: 0.8802
# Epoch 32: val_accuracy did not improve from 0.85366
# 8/8 [==============================] - 2s 231ms/step - loss: 0.7444 - accuracy: 0.8802 - val_loss: 0.8141 - val_accuracy: 0.8415 - lr: 0.0010
# Epoch 33/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7430 - accuracy: 0.8824
# Epoch 33: val_accuracy improved from 0.85366 to 0.85671, saving model to model/training_33.keras
# 8/8 [==============================] - 2s 266ms/step - loss: 0.7430 - accuracy: 0.8824 - val_loss: 0.8008 - val_accuracy: 0.8567 - lr: 0.0010
# Epoch 34/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7435 - accuracy: 0.8725
# Epoch 34: val_accuracy did not improve from 0.85671
# 8/8 [==============================] - 2s 234ms/step - loss: 0.7435 - accuracy: 0.8725 - val_loss: 0.8156 - val_accuracy: 0.8445 - lr: 0.0010
# Epoch 35/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7443 - accuracy: 0.8780
# Epoch 35: val_accuracy did not improve from 0.85671
# 8/8 [==============================] - 2s 269ms/step - loss: 0.7443 - accuracy: 0.8780 - val_loss: 0.8010 - val_accuracy: 0.8537 - lr: 0.0010
# Epoch 36/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7506 - accuracy: 0.8856
# Epoch 36: val_accuracy did not improve from 0.85671
# 8/8 [==============================] - 2s 240ms/step - loss: 0.7506 - accuracy: 0.8856 - val_loss: 0.8124 - val_accuracy: 0.8415 - lr: 0.0010
# Epoch 37/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7559 - accuracy: 0.8813
# Epoch 37: val_accuracy improved from 0.85671 to 0.86585, saving model to model/training_37.keras
# 8/8 [==============================] - 2s 276ms/step - loss: 0.7559 - accuracy: 0.8813 - val_loss: 0.7923 - val_accuracy: 0.8659 - lr: 0.0010
# Epoch 38/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7632 - accuracy: 0.8747
# Epoch 38: val_accuracy did not improve from 0.86585
# 8/8 [==============================] - 2s 239ms/step - loss: 0.7632 - accuracy: 0.8747 - val_loss: 0.8074 - val_accuracy: 0.8384 - lr: 0.0010
# Epoch 39/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7243 - accuracy: 0.8965
# Epoch 39: val_accuracy did not improve from 0.86585
# 8/8 [==============================] - 2s 263ms/step - loss: 0.7243 - accuracy: 0.8965 - val_loss: 0.7895 - val_accuracy: 0.8659 - lr: 0.0010
# Epoch 40/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7373 - accuracy: 0.8799
# Epoch 40: val_accuracy did not improve from 0.86585
# 8/8 [==============================] - 2s 250ms/step - loss: 0.7373 - accuracy: 0.8799 - val_loss: 0.7983 - val_accuracy: 0.8659 - lr: 0.0010
# Epoch 41/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7219 - accuracy: 0.8911
# Epoch 41: val_accuracy did not improve from 0.86585
# 8/8 [==============================] - 2s 230ms/step - loss: 0.7219 - accuracy: 0.8911 - val_loss: 0.7890 - val_accuracy: 0.8628 - lr: 0.0010
# Epoch 42/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7274 - accuracy: 0.8845
# Epoch 42: val_accuracy improved from 0.86585 to 0.87195, saving model to model/training_42.keras
# 8/8 [==============================] - 2s 266ms/step - loss: 0.7274 - accuracy: 0.8845 - val_loss: 0.7878 - val_accuracy: 0.8720 - lr: 0.0010
# Epoch 43/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7246 - accuracy: 0.8998
# Epoch 43: val_accuracy did not improve from 0.87195
# 8/8 [==============================] - 2s 234ms/step - loss: 0.7246 - accuracy: 0.8998 - val_loss: 0.8003 - val_accuracy: 0.8476 - lr: 0.0010
# Epoch 44/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7344 - accuracy: 0.8769
# Epoch 44: val_accuracy did not improve from 0.87195
# 8/8 [==============================] - 2s 227ms/step - loss: 0.7344 - accuracy: 0.8769 - val_loss: 0.7884 - val_accuracy: 0.8537 - lr: 0.0010
# Epoch 45/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7163 - accuracy: 0.9020
# Epoch 45: val_accuracy did not improve from 0.87195
# 8/8 [==============================] - 2s 225ms/step - loss: 0.7163 - accuracy: 0.9020 - val_loss: 0.8050 - val_accuracy: 0.8445 - lr: 0.0010
# Epoch 46/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.7091 - accuracy: 0.8996
# Epoch 46: val_accuracy improved from 0.87195 to 0.87805, saving model to model/training_46.keras
# 8/8 [==============================] - 2s 250ms/step - loss: 0.7100 - accuracy: 0.8987 - val_loss: 0.7814 - val_accuracy: 0.8780 - lr: 0.0010
# Epoch 47/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7133 - accuracy: 0.9074
# Epoch 47: val_accuracy did not improve from 0.87805
# 8/8 [==============================] - 2s 231ms/step - loss: 0.7133 - accuracy: 0.9074 - val_loss: 0.7948 - val_accuracy: 0.8506 - lr: 0.0010
# Epoch 48/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7103 - accuracy: 0.8987
# Epoch 48: val_accuracy did not improve from 0.87805
# 8/8 [==============================] - 2s 225ms/step - loss: 0.7103 - accuracy: 0.8987 - val_loss: 0.7773 - val_accuracy: 0.8598 - lr: 0.0010
# Epoch 49/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7203 - accuracy: 0.8943
# Epoch 49: val_accuracy did not improve from 0.87805
# 8/8 [==============================] - 2s 228ms/step - loss: 0.7203 - accuracy: 0.8943 - val_loss: 0.7861 - val_accuracy: 0.8598 - lr: 0.0010
# Epoch 50/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7106 - accuracy: 0.8976
# Epoch 50: val_accuracy did not improve from 0.87805
# 8/8 [==============================] - 2s 235ms/step - loss: 0.7106 - accuracy: 0.8976 - val_loss: 0.7810 - val_accuracy: 0.8689 - lr: 0.0010
# Epoch 51/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.7093 - accuracy: 0.9018
# Epoch 51: val_accuracy did not improve from 0.87805
# 8/8 [==============================] - 2s 220ms/step - loss: 0.7111 - accuracy: 0.8998 - val_loss: 0.7870 - val_accuracy: 0.8598 - lr: 9.0484e-04
# Epoch 52/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7022 - accuracy: 0.9096
# Epoch 52: val_accuracy did not improve from 0.87805
# 8/8 [==============================] - 2s 230ms/step - loss: 0.7022 - accuracy: 0.9096 - val_loss: 0.7839 - val_accuracy: 0.8598 - lr: 8.1873e-04
# Epoch 53/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6980 - accuracy: 0.9150
# Epoch 53: val_accuracy did not improve from 0.87805
# 8/8 [==============================] - 2s 237ms/step - loss: 0.6980 - accuracy: 0.9150 - val_loss: 0.7760 - val_accuracy: 0.8750 - lr: 7.4082e-04
# Epoch 54/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7057 - accuracy: 0.9096
# Epoch 54: val_accuracy did not improve from 0.87805
# 8/8 [==============================] - 2s 247ms/step - loss: 0.7057 - accuracy: 0.9096 - val_loss: 0.7801 - val_accuracy: 0.8659 - lr: 6.7032e-04
# Epoch 55/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6958 - accuracy: 0.9150
# Epoch 55: val_accuracy improved from 0.87805 to 0.88415, saving model to model/training_55.keras
# 8/8 [==============================] - 2s 296ms/step - loss: 0.6958 - accuracy: 0.9150 - val_loss: 0.7747 - val_accuracy: 0.8841 - lr: 6.0653e-04
# Epoch 56/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7023 - accuracy: 0.9041
# Epoch 56: val_accuracy did not improve from 0.88415
# 8/8 [==============================] - 2s 236ms/step - loss: 0.7023 - accuracy: 0.9041 - val_loss: 0.7835 - val_accuracy: 0.8628 - lr: 5.4881e-04
# Epoch 57/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.9107
# Epoch 57: val_accuracy did not improve from 0.88415
# 8/8 [==============================] - 2s 238ms/step - loss: 0.6932 - accuracy: 0.9107 - val_loss: 0.7769 - val_accuracy: 0.8780 - lr: 4.9659e-04
# Epoch 58/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.9180
# Epoch 58: val_accuracy did not improve from 0.88415
# 8/8 [==============================] - 2s 235ms/step - loss: 0.6938 - accuracy: 0.9180 - val_loss: 0.7753 - val_accuracy: 0.8689 - lr: 4.4933e-04
# Epoch 59/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6914 - accuracy: 0.9096
# Epoch 59: val_accuracy did not improve from 0.88415
# 8/8 [==============================] - 2s 227ms/step - loss: 0.6914 - accuracy: 0.9096 - val_loss: 0.7787 - val_accuracy: 0.8659 - lr: 4.0657e-04
# Epoch 60/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6903 - accuracy: 0.9141
# Epoch 60: val_accuracy did not improve from 0.88415
# 8/8 [==============================] - 2s 217ms/step - loss: 0.6892 - accuracy: 0.9150 - val_loss: 0.7794 - val_accuracy: 0.8750 - lr: 3.6788e-04
# Epoch 61/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6965 - accuracy: 0.9085
# Epoch 61: val_accuracy did not improve from 0.88415
# 8/8 [==============================] - 2s 256ms/step - loss: 0.6965 - accuracy: 0.9085 - val_loss: 0.7821 - val_accuracy: 0.8689 - lr: 3.3287e-04
# Epoch 62/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6976 - accuracy: 0.9041
# Epoch 62: val_accuracy did not improve from 0.88415
# 8/8 [==============================] - 2s 257ms/step - loss: 0.6976 - accuracy: 0.9041 - val_loss: 0.7731 - val_accuracy: 0.8750 - lr: 3.0119e-04
# Epoch 63/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.9172
# Epoch 63: val_accuracy did not improve from 0.88415
# 8/8 [==============================] - 2s 235ms/step - loss: 0.6920 - accuracy: 0.9172 - val_loss: 0.7731 - val_accuracy: 0.8841 - lr: 2.7253e-04
# Epoch 64/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6778 - accuracy: 0.9259
# Epoch 64: val_accuracy did not improve from 0.88415
# 8/8 [==============================] - 2s 226ms/step - loss: 0.6778 - accuracy: 0.9259 - val_loss: 0.7725 - val_accuracy: 0.8811 - lr: 2.4660e-04
# Epoch 65/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6957 - accuracy: 0.9031
# Epoch 65: val_accuracy did not improve from 0.88415
# 8/8 [==============================] - 2s 253ms/step - loss: 0.6957 - accuracy: 0.9031 - val_loss: 0.7708 - val_accuracy: 0.8841 - lr: 2.2313e-04
# Epoch 66/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6852 - accuracy: 0.9314
# Epoch 66: val_accuracy did not improve from 0.88415
# 8/8 [==============================] - 2s 230ms/step - loss: 0.6852 - accuracy: 0.9314 - val_loss: 0.7747 - val_accuracy: 0.8841 - lr: 2.0190e-04
# Epoch 67/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6943 - accuracy: 0.9118
# Epoch 67: val_accuracy improved from 0.88415 to 0.88720, saving model to model/training_67.keras
# 8/8 [==============================] - 2s 263ms/step - loss: 0.6943 - accuracy: 0.9118 - val_loss: 0.7767 - val_accuracy: 0.8872 - lr: 1.8268e-04
# Epoch 68/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6847 - accuracy: 0.9227
# Epoch 68: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 233ms/step - loss: 0.6847 - accuracy: 0.9227 - val_loss: 0.7757 - val_accuracy: 0.8811 - lr: 1.6530e-04
# Epoch 69/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6762 - accuracy: 0.9292
# Epoch 69: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 230ms/step - loss: 0.6762 - accuracy: 0.9292 - val_loss: 0.7743 - val_accuracy: 0.8811 - lr: 1.4957e-04
# Epoch 70/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6916 - accuracy: 0.9216
# Epoch 70: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 229ms/step - loss: 0.6916 - accuracy: 0.9216 - val_loss: 0.7750 - val_accuracy: 0.8841 - lr: 1.3534e-04
# Epoch 71/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6834 - accuracy: 0.9237
# Epoch 71: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 238ms/step - loss: 0.6834 - accuracy: 0.9237 - val_loss: 0.7759 - val_accuracy: 0.8811 - lr: 1.2246e-04
# Epoch 72/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6846 - accuracy: 0.9161
# Epoch 72: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 239ms/step - loss: 0.6846 - accuracy: 0.9161 - val_loss: 0.7778 - val_accuracy: 0.8872 - lr: 1.1080e-04
# Epoch 73/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6682 - accuracy: 0.9292
# Epoch 73: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 231ms/step - loss: 0.6682 - accuracy: 0.9292 - val_loss: 0.7756 - val_accuracy: 0.8841 - lr: 1.0026e-04
# Epoch 74/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6891 - accuracy: 0.9085
# Epoch 74: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 255ms/step - loss: 0.6891 - accuracy: 0.9085 - val_loss: 0.7748 - val_accuracy: 0.8811 - lr: 9.0718e-05
# Epoch 75/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6802 - accuracy: 0.9183
# Epoch 75: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 230ms/step - loss: 0.6802 - accuracy: 0.9183 - val_loss: 0.7730 - val_accuracy: 0.8811 - lr: 8.2085e-05
# Epoch 76/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6860 - accuracy: 0.9205
# Epoch 76: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 230ms/step - loss: 0.6860 - accuracy: 0.9205 - val_loss: 0.7734 - val_accuracy: 0.8841 - lr: 7.4274e-05
# Epoch 77/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6831 - accuracy: 0.9292
# Epoch 77: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 227ms/step - loss: 0.6831 - accuracy: 0.9292 - val_loss: 0.7728 - val_accuracy: 0.8811 - lr: 6.7206e-05
# Epoch 78/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6956 - accuracy: 0.9074
# Epoch 78: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 225ms/step - loss: 0.6956 - accuracy: 0.9074 - val_loss: 0.7730 - val_accuracy: 0.8841 - lr: 6.0810e-05
# Epoch 79/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6807 - accuracy: 0.9227
# Epoch 79: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 225ms/step - loss: 0.6807 - accuracy: 0.9227 - val_loss: 0.7752 - val_accuracy: 0.8811 - lr: 5.5023e-05
# Epoch 80/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6850 - accuracy: 0.9205
# Epoch 80: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 239ms/step - loss: 0.6850 - accuracy: 0.9205 - val_loss: 0.7759 - val_accuracy: 0.8811 - lr: 4.9787e-05
# Epoch 81/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6835 - accuracy: 0.9161
# Epoch 81: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 239ms/step - loss: 0.6835 - accuracy: 0.9161 - val_loss: 0.7754 - val_accuracy: 0.8811 - lr: 4.5049e-05
# Epoch 82/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6771 - accuracy: 0.9205
# Epoch 82: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 259ms/step - loss: 0.6771 - accuracy: 0.9205 - val_loss: 0.7738 - val_accuracy: 0.8811 - lr: 4.0762e-05
# Epoch 83/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6686 - accuracy: 0.9314
# Epoch 83: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 228ms/step - loss: 0.6686 - accuracy: 0.9314 - val_loss: 0.7733 - val_accuracy: 0.8811 - lr: 3.6883e-05
# Epoch 84/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6865 - accuracy: 0.9216
# Epoch 84: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 226ms/step - loss: 0.6865 - accuracy: 0.9216 - val_loss: 0.7734 - val_accuracy: 0.8872 - lr: 3.3373e-05
# Epoch 85/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6775 - accuracy: 0.9307
# Epoch 85: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 236ms/step - loss: 0.6775 - accuracy: 0.9307 - val_loss: 0.7740 - val_accuracy: 0.8872 - lr: 3.0197e-05
# Epoch 86/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6804 - accuracy: 0.9237
# Epoch 86: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 227ms/step - loss: 0.6804 - accuracy: 0.9237 - val_loss: 0.7742 - val_accuracy: 0.8872 - lr: 2.7324e-05
# Epoch 87/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6837 - accuracy: 0.9237
# Epoch 87: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 241ms/step - loss: 0.6837 - accuracy: 0.9237 - val_loss: 0.7741 - val_accuracy: 0.8872 - lr: 2.4724e-05
# Epoch 88/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6792 - accuracy: 0.9205
# Epoch 88: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 236ms/step - loss: 0.6792 - accuracy: 0.9205 - val_loss: 0.7744 - val_accuracy: 0.8841 - lr: 2.2371e-05
# Epoch 89/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6862 - accuracy: 0.9150
# Epoch 89: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 227ms/step - loss: 0.6862 - accuracy: 0.9150 - val_loss: 0.7745 - val_accuracy: 0.8841 - lr: 2.0242e-05
# Epoch 90/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6815 - accuracy: 0.9196
# Epoch 90: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 220ms/step - loss: 0.6839 - accuracy: 0.9183 - val_loss: 0.7743 - val_accuracy: 0.8841 - lr: 1.8316e-05
# Epoch 91/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.9063
# Epoch 91: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 228ms/step - loss: 0.6869 - accuracy: 0.9063 - val_loss: 0.7741 - val_accuracy: 0.8811 - lr: 1.6573e-05
# Epoch 92/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6823 - accuracy: 0.9292
# Epoch 92: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 228ms/step - loss: 0.6823 - accuracy: 0.9292 - val_loss: 0.7742 - val_accuracy: 0.8841 - lr: 1.4996e-05
# Epoch 93/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6877 - accuracy: 0.9237
# Epoch 93: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 233ms/step - loss: 0.6877 - accuracy: 0.9237 - val_loss: 0.7743 - val_accuracy: 0.8841 - lr: 1.3569e-05
# Epoch 94/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6782 - accuracy: 0.9286
# Epoch 94: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 217ms/step - loss: 0.6781 - accuracy: 0.9292 - val_loss: 0.7742 - val_accuracy: 0.8841 - lr: 1.2277e-05
# Epoch 95/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6856 - accuracy: 0.9270
# Epoch 95: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 228ms/step - loss: 0.6856 - accuracy: 0.9270 - val_loss: 0.7737 - val_accuracy: 0.8872 - lr: 1.1109e-05
# Epoch 96/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6742 - accuracy: 0.9357
# Epoch 96: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 229ms/step - loss: 0.6742 - accuracy: 0.9357 - val_loss: 0.7734 - val_accuracy: 0.8872 - lr: 1.0052e-05
# Epoch 97/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6778 - accuracy: 0.9259
# Epoch 97: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 232ms/step - loss: 0.6778 - accuracy: 0.9259 - val_loss: 0.7735 - val_accuracy: 0.8872 - lr: 9.0953e-06
# Epoch 98/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6876 - accuracy: 0.9216
# Epoch 98: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 233ms/step - loss: 0.6876 - accuracy: 0.9216 - val_loss: 0.7736 - val_accuracy: 0.8872 - lr: 8.2297e-06
# Epoch 99/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6898 - accuracy: 0.9172
# Epoch 99: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 232ms/step - loss: 0.6898 - accuracy: 0.9172 - val_loss: 0.7737 - val_accuracy: 0.8872 - lr: 7.4466e-06
# Epoch 100/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6865 - accuracy: 0.9063
# Epoch 100: val_accuracy did not improve from 0.88720
# 8/8 [==============================] - 2s 228ms/step - loss: 0.6865 - accuracy: 0.9063 - val_loss: 0.7737 - val_accuracy: 0.8872 - lr: 6.7379e-06

# %% [markdown]
# ## Evaluate

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# model = load_model('/home/alexandros/radar/model_epoch_02.keras')
model.evaluate(x_train,y_train)
model.evaluate(x_val,y_val)
model.evaluate(x_test, y_test)
# Out:
# 33/33 [==============================] - 1s 37ms/step - loss: 0.6289 - accuracy: 0.9570
# 11/11 [==============================] - 0s 36ms/step - loss: 0.7737 - accuracy: 0.8872
# 9/9 [==============================] - 0s 48ms/step - loss: 0.7570 - accuracy: 0.8817
# [0.7570282816886902, 0.8816794157028198]

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = model.predict(x_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_test,axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
# plot the confusion matrix
activity=['drink','fall','pick','sit','stand','walk']
plot_confusion_matrix(confusion_mtx, classes = activity )
# Out:
# 9/9 [==============================] - 1s 34ms/step
